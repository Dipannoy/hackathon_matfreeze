# %%
import torch

rep_path = '/workspace/hackathon_matfreeze/ft_saved_models/bandgap_finetuning_rep_extract/representations/train/representations_epoch1.pt'
reps = torch.load(rep_path, weights_only=False)
crystal_embeddings_pretrain = reps['crystal']  # Shape: (N, 128)
print(f"Saved {crystal_embeddings.shape[0]} samples")
# Out:
# Saved 70 samples

# %%
rep_path = '/workspace/hackathon_matfreeze/ft_saved_models/bandgap_finetuning_rep_extract/representations/train/representations_epoch200.pt'
reps = torch.load(rep_path, weights_only=False)
crystal_embeddings_ft_full = reps['crystal']  # Shape: (N, 128)
print(f"Saved {crystal_embeddings.shape[0]} samples")
# Out:
# Saved 70 samples

# %%
print(crystal_embeddings[0].shape)
# Out:
# torch.Size([128])

# %%
print(crystal_embeddings[1])
# Out:
# tensor([  3.8447,   6.4125,  -4.4010,  -4.0511,   2.2027,  -2.3214,   2.1207,
#          -2.4822,  -2.1819,  -0.7640,   6.9856,  -4.3590,   2.7464,   2.4401,
#         -10.4244,   4.3677,  -3.1501,   4.4486,   4.2895,  -1.8882,  -5.4996,
#          -2.9323,   0.8754,  -5.7120,   6.3687,  -3.9680,  -0.1378,   4.3870,
#          -4.4511,   0.3417,   2.3113,  -3.3112,  -2.8362,   2.4768,  -5.0673,
#           0.2706,   2.4167,   3.7631,  -0.9383,  -1.9815,  -1.0865,   1.5522,
#          -8.2224,  -6.0716,   1.5808,   5.9718,   6.7484,  -4.3320,  -1.8228,
#          -1.0699,   2.1415,  -7.1192,   0.8513,  -6.1197,  -6.4078,   1.0428,
#           8.6669,  -7.9427,   5.7558,  -3.3185,   2.2996, -12.0804, -12.1078,
#           5.1665,  -1.3527,  -6.1780,   5.2271,  -0.1795,  -9.2166,  -3.9478,
#           6.8370,  -8.7170,   8.5922,   7.8267,  -2.7619,   1.6435,   3.2657,
#           4.8498,   7.1262,  -5.9069,   4.5091,   0.0198,  -2.8490, -11.8647,
#           0.2548,   1.1385,   0.5851,   3.8581,   2.3518,   1.8731,   4.9239,
#           5.6389,   4.3518,  -0.1295,  -2.4366,   1.4013,   0.6065,   1.5062,
#          -0.1809,   2.3334,   2.0392,  -2.8811,  -0.8586,   3.0507,  -5.2245,
#           8.4861,  -3.5130,  -3.4533,  -7.5769,  -0.5064,   3.4656,   5.0158,
#          -3.9655,   4.0387,  -0.4023,  -3.2398,   0.7081,  -0.0125,   7.4112,
#          -4.2379,  -4.2467,   4.8667,  -7.0158,   4.9277,   1.9802,   2.6316,
#          -1.0832,  -4.6098])

# %%
print(crystal_embeddings[2])
# Out:
# tensor([  3.1289,   3.6288, -10.1857, -18.7283,   8.6360,  -7.8067,  -0.1644,
#          -0.9567,   5.0543,  -3.7969,  10.1496,   2.6075,   3.7947,   3.1579,
#          -7.3263,  15.8206,   4.2066,   1.7307,   5.7242,   1.3210,  -8.6965,
#          -1.0435,   6.3991, -10.9512,  15.3328,  -0.8143,   3.9409,   3.4312,
#          -7.9574,   2.9063,  -0.4869,  -6.3564,  -8.8585,   7.5835,  -9.0744,
#          -9.7969,  -0.2679,   3.7096,   2.2857, -13.6491,  -0.8468,  -8.0672,
#          -9.3364, -10.2155,   0.6717,  14.0205,  14.5836,  -5.3535,  -0.0813,
#          -4.9497,   5.8254, -10.8778,   2.2487,  -9.8058,  -8.4088,  12.5176,
#           7.4776, -14.2796,  11.6682,  -3.9625,  -2.1237, -17.8050, -20.6502,
#           1.0188,  -2.5960,  -7.6000,   6.8776,  11.3711,  -7.1239,  -5.2120,
#          18.8634, -16.3122,   6.9173,  10.2213,  -1.6741,   4.7317,   8.6018,
#           9.2330,  11.6317,  -7.9259,   6.7925,  -7.3194,  -8.2379, -13.5245,
#          -4.3523,  -5.2211,   7.2204,  -0.2036,   1.1788,   6.6820,   6.5280,
#           1.0325,  11.4465,  -4.5709,  -5.1702,  13.1971,  -6.4482,  -3.2773,
#           2.2491,   3.7354,   6.8873,  -0.6666,   0.0318,   7.7347, -18.1187,
#          21.6662,  -7.0259,   0.1747,  -8.2300,   1.0852,   8.1162,   6.0474,
#           0.3132,   7.7562,   1.6038,  -3.8601,   6.9729,   9.3292,   6.6427,
#          -5.8050,   5.5167,   6.2810, -14.5232,   6.7000,   2.1301,   0.9515,
#          11.3611, -17.9278])
